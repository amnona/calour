# %%
import calour as ca
# %matplotlib notebook

# %%
exp = ca.read_amplicon('data/grape-soil.biom','data/grape-soil.sample.txt',normalize=10000,filter_reads=1000, sparse=False)

# %%
exp
# Out:
# AmpliconExperiment grape-soil.biom with 400 samples, 42159 features

# %%
exp.cluster_features(50,inplace=True)
# Out:
# AmpliconExperiment grape-soil.biom with 400 samples, 6125 features

# %%
exp.sample_metadata.columns
# Out:
# Index(['#SampleID', 'BarcodeSequence', 'LinkerPrimerSequence', 'center_name',
#        'center_project_name', 'emp_status', 'experiment_design_description',
#        'illumina_technology', 'key_seq', 'library_construction_protocol',
#        'linker', 'pcr_primers', 'platform', 'region', 'run_center', 'run_date',
#        'run_prefix', 'samp_size', 'sample_center', 'sequencing_meth',
#        'study_center', 'target_gene', 'target_subfragment',
#        'agrochem_addition', 'altitude', 'annual_season_precpt',
#        'annual_season_temp', 'anonymized_name', 'area', 'area_2',
#        'assigned_from_geo', 'c_n_ratio', 'carbon_perc', 'clone', 'cm_to_stem',
#        'collection_timestamp', 'common_name', 'country', 'cur_land_use',
#        'depth', 'dna_extracted', 'drainage_class', 'elevation', 'env_biome',
#        'env_feature', 'env_matter', 'extracted_dna_avail_now',
#        'host_subject_id', 'latitude', 'longitude', 'nitrogen_perc',
# ...

# %%
exps=exp.sort_samples('ph')

# %%
exps.cluster_features(inplace=True)
# Out:
# AmpliconExperiment grape-soil.biom with 400 samples, 6125 features

# %%
exps.plot_sort('env_matter',gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr=exps.filter_samples('env_matter','ENVO:bulk soil')

# %%
sr.cluster_features(10,inplace=True)
# Out:
# AmpliconExperiment grape-soil.biom with 64 samples, 5164 features

# %%
sr.plot(gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cc=sr.correlation('ph')
# Out:
# 2017-03-03 11:46:49 WARNING NaN values encountered in labels for correlation. Ignoring these samples

# %%
cc.plot_sort('env_matter',gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">
